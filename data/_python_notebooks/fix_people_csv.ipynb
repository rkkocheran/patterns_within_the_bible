# %%
import pandas as pd

# %%
# Import CSV file - replace 'filename.csv' with your actual CSV file name
df = pd.read_csv(r"..\acts_and_miracles\references\rouse_metav_data\data\CSV\People.csv")

# %%
list(df.columns)
# Out:
# ['personLookup',
#  'status',
#  'personID',
#  'displayTitle',
#  'name',
#  'surname',
#  'alsoCalled',
#  'isProperName',
#  'ambiguous',
#  'Disambiguation (temp)',
#  'gender',
#  'occupations',
#  'birthYear',
#  'minYear',
#  'deathYear',
#  'maxYear',
#  'birthPlace',
#  'deathPlace',
#  'memberOf',
#  'eastons',
#  'dictText',
#  'events',
#  'eventGroups',
#  'verseCount',
#  'verses',
#  'mother',
#  'father',
#  'partners',
#  'children',
#  'siblings',
#  'halfSiblingsSameMother',
#  'halfSiblingsSameFather',
#  'chaptersWritten',
#  'alphaGroup',
#  'slug',
#  'modified']

# %%
print("Header - First 5 rows:")
df.head()

# Print header (first 5 rows)
# Out:
# Header - First 5 rows:
#   personLookup   status  personID displayTitle     name surname alsoCalled  \
# 0      aaron_1  publish         1        Aaron    Aaron     NaN        NaN
# 1    abagtha_3      wip         3      Abagtha  Abagtha     NaN        NaN
# 2       abda_4      wip         4         Abda     Abda     NaN        NaN
# 3     abdeel_5      wip         5       Abdeel   Abdeel     NaN        NaN
# 4       abdi_6      wip         6         Abdi     Abdi     NaN        NaN
#
#   isProperName ambiguous                              Disambiguation (temp)  \
# 0      checked       NaN                                                NaN
# 1      checked       NaN                                                NaN
# 2      checked       NaN                                                NaN
# 3      checked       NaN                                                NaN
# 4      checked   checked  Abdi - A Levite, father of Kishi and grandfath...
#
# ...

# %%
print("\n" + "="*50 + "\n")

# Print footer (last 5 rows)
print("Footer - Last 5 rows:")
df.tail()
# Out:
# ...
#
# Footer - Last 5 rows:
#           personLookup status  personID displayTitle         name surname  \
# 3064          zur_3109    wip      3109          Zur          Zur     NaN
# 3065          zur_3110    wip      3110          Zur          Zur     NaN
# 3066          zur_3111    wip      3111          Zur          Zur     NaN
# 3067       zuriel_3112    wip      3112       Zuriel       Zuriel     NaN
# 3068  zurishaddai_3113    wip      3113  Zurishaddai  Zurishaddai     NaN
#
#      alsoCalled isProperName ambiguous  \
# 3064        NaN      checked   checked
# 3065        NaN      checked   checked
# 3066        NaN      checked   checked
# 3067        NaN      checked       NaN
# 3068        NaN      checked       NaN
#
#                                   Disambiguation (temp)  ...      father  \
# 3064                           Zur (A prince of Midian)  ...         NaN
# 3065  Zur was one of the Midianite Chiefs defeated b...  ...         NaN
# ...

# %%
df.dictText
# Out:
# 0       The eldest son of Amram and Jochebed, a daught...
# 1       One of the seven eunuchs in Ahasuerus’s court ...
# 2       The father of Adoniram, whom Solomon set over ...
# 3       Servant of God, ([Jer. 36:26](/jer#Jer.36.26))...
# 4                         [1 Chr. 6:44](/1chr#1Chr.6.44).
#                               ...
# 3064                                                  NaN
# 3065    One of the five Midianite kings whom the Israe...
# 3066        A Benjamite ([1 Chr. 8:30](/1chr#1Chr.8.30)).
# 3067    Rock of God, chief of the family of the Merari...
# 3068    Rock of the Almighty, the father of Shelumiel,...
# Name: dictText, Length: 3069, dtype: object

# %%
x=dfa

# %%
x.dictText
# Out:
# 996    (A.S. and Dutch God; Dan. Gud; Ger. Gott), the...
# Name: dictText, dtype: object

# %%
df.to_csv(r".\PeoplePy.csv")
