# %%
import pandas as pd
import re

# %%
num_df = pd.read_excel('../acts_and_miracles/acts_and_miracles_preprep.xlsx', sheet_name='book_to_number', header=0)
num_df
# Out:
#       book_name  book_number
# 0       Genesis            1
# 1        Exodus            2
# 2     Leviticus            3
# 3       Numbers            4
# 4   Deuteronomy            5
# ..          ...          ...
# 61       1 John           62
# 62       2 John           63
# 63       3 John           64
# 64         Jude           65
# 65   Revelation           66
#
# [66 rows x 2 columns]

# %%
df = pd.read_excel('../acts_and_miracles/acts_and_miracles_preprep.xlsx', sheet_name='acts_and_miracles')
df['Reference'] = df['Reference'].str.replace('Psalm', 'Psalms')
df
# Out:
#                                             Description  \
# 0                     Creation of the heavens and earth
# 1                       God speaks light into existence
# 2     God speaks to separate waters and create firma...
# 3           God speaks dry land and seas into existence
# 4                  God speaks vegetation into existence
# ...                                                 ...
# 2985           Tree of life bears twelve kinds of fruit
# 2986            No more curse, night, or need for light
# 2987                      Angel shows John these things
# 2988                  Jesus declares His coming quickly
# 2989                        Spirit and Bride say "Come"
#
#      Primary / Secondary Category                Reference          Location  \
# 0                 Cosmic/Creation          Genesis 1:1-2:3             Earth
# 1                 Speech/Creation              Genesis 1:3             Earth
# 2                 Speech/Creation            Genesis 1:6-8             Earth
# 3                 Speech/Creation           Genesis 1:9-10             Earth
# 4                 Speech/Creation          Genesis 1:11-13             Earth
# ...                           ...                      ...               ...
# 2985                    Provision          Revelation 22:2     New Jerusalem
# 2986               Transformation        Revelation 22:3-5     New Jerusalem
# 2987                   Revelation        Revelation 22:6-9  Island of Patmos
# 2988                      Promise  Revelation 22:7, 12, 20  Island of Patmos
# 2989                   Invitation         Revelation 22:17  Island of Patmos
#
#                    Date           Messenger       Supporting References/Notes
# 0     Beginning of Time                 GOD                               NaN
# 1     Beginning of Time                 GOD                               NaN
# 2     Beginning of Time                 GOD                               NaN
# 3     Beginning of Time                 GOD                               NaN
# 4     Beginning of Time                 GOD                               NaN
# ...                 ...                 ...                               ...
# 2985             Future                 God  Genesis 2:9; 3:22; Ezekiel 47:12
# 2986             Future                 God      Genesis 3:17; Zechariah 14:7
# 2987           c. 95 AD               Angel                 Daniel 8:26; 12:4
# 2988           c. 95 AD        Jesus Christ        Malachi 3:1; Matthew 16:27
# 2989           c. 95 AD  Holy Spirit/Church                       Isaiah 55:1
#
# [2990 rows x 7 columns]

# %%
def extract_words_left_of_numbers(text):
    """
    Extract all words left of middle-occurring numbers,
    or leftmost number+words if starts with number
    """
    if pd.isna(text):
        return ""
    
    text = str(text).strip()
    
    # Case 1: Starts with number - get number + following words until next number
    if re.match(r'^\d', text):
        pattern = r'^(\d+\s*[A-Za-z]+(?:\s+[A-Za-z]+)*)'
        match = re.search(pattern, text)
        return match.group(1).strip() if match else ""
    
    # Case 2: Starts with letters - get all words before first number
    else:
        pattern = r'^([A-Za-z]+(?:\s+[A-Za-z]+)*)'
        match = re.search(pattern, text)
        return match.group(1).strip() if match else ""

# %%
df['book_name'] = [extract_words_left_of_numbers(ref) for ref in df.Reference]
df
# Out:
#                                             Description  \
# 0                     Creation of the heavens and earth
# 1                       God speaks light into existence
# 2     God speaks to separate waters and create firma...
# 3           God speaks dry land and seas into existence
# 4                  God speaks vegetation into existence
# ...                                                 ...
# 2985           Tree of life bears twelve kinds of fruit
# 2986            No more curse, night, or need for light
# 2987                      Angel shows John these things
# 2988                  Jesus declares His coming quickly
# 2989                        Spirit and Bride say "Come"
#
#      Primary / Secondary Category                Reference          Location  \
# 0                 Cosmic/Creation          Genesis 1:1-2:3             Earth
# 1                 Speech/Creation              Genesis 1:3             Earth
# 2                 Speech/Creation            Genesis 1:6-8             Earth
# 3                 Speech/Creation           Genesis 1:9-10             Earth
# 4                 Speech/Creation          Genesis 1:11-13             Earth
# ...                           ...                      ...               ...
# 2985                    Provision          Revelation 22:2     New Jerusalem
# 2986               Transformation        Revelation 22:3-5     New Jerusalem
# 2987                   Revelation        Revelation 22:6-9  Island of Patmos
# 2988                      Promise  Revelation 22:7, 12, 20  Island of Patmos
# 2989                   Invitation         Revelation 22:17  Island of Patmos
#
#                    Date           Messenger       Supporting References/Notes  \
# 0     Beginning of Time                 GOD                               NaN
# 1     Beginning of Time                 GOD                               NaN
# 2     Beginning of Time                 GOD                               NaN
# 3     Beginning of Time                 GOD                               NaN
# 4     Beginning of Time                 GOD                               NaN
# ...                 ...                 ...                               ...
# 2985             Future                 God  Genesis 2:9; 3:22; Ezekiel 47:12
# 2986             Future                 God      Genesis 3:17; Zechariah 14:7
# 2987           c. 95 AD               Angel                 Daniel 8:26; 12:4
# 2988           c. 95 AD        Jesus Christ        Malachi 3:1; Matthew 16:27
# 2989           c. 95 AD  Holy Spirit/Church                       Isaiah 55:1
#
#        book_name
# 0        Genesis
# 1        Genesis
# 2        Genesis
# 3        Genesis
# 4        Genesis
# ...          ...
# 2985  Revelation
# 2986  Revelation
# 2987  Revelation
# 2988  Revelation
# 2989  Revelation
#
# [2990 rows x 8 columns]

# %%
mergeddf = pd.merge(df, num_df, how='left', on='book_name')
mergeddf
# Out:
#                                             Description  \
# 0                     Creation of the heavens and earth
# 1                       God speaks light into existence
# 2     God speaks to separate waters and create firma...
# 3           God speaks dry land and seas into existence
# 4                  God speaks vegetation into existence
# ...                                                 ...
# 2985           Tree of life bears twelve kinds of fruit
# 2986            No more curse, night, or need for light
# 2987                      Angel shows John these things
# 2988                  Jesus declares His coming quickly
# 2989                        Spirit and Bride say "Come"
#
#      Primary / Secondary Category                Reference          Location  \
# 0                 Cosmic/Creation          Genesis 1:1-2:3             Earth
# 1                 Speech/Creation              Genesis 1:3             Earth
# 2                 Speech/Creation            Genesis 1:6-8             Earth
# 3                 Speech/Creation           Genesis 1:9-10             Earth
# 4                 Speech/Creation          Genesis 1:11-13             Earth
# ...                           ...                      ...               ...
# 2985                    Provision          Revelation 22:2     New Jerusalem
# 2986               Transformation        Revelation 22:3-5     New Jerusalem
# 2987                   Revelation        Revelation 22:6-9  Island of Patmos
# 2988                      Promise  Revelation 22:7, 12, 20  Island of Patmos
# 2989                   Invitation         Revelation 22:17  Island of Patmos
#
#                    Date           Messenger       Supporting References/Notes  \
# 0     Beginning of Time                 GOD                               NaN
# 1     Beginning of Time                 GOD                               NaN
# 2     Beginning of Time                 GOD                               NaN
# 3     Beginning of Time                 GOD                               NaN
# 4     Beginning of Time                 GOD                               NaN
# ...                 ...                 ...                               ...
# 2985             Future                 God  Genesis 2:9; 3:22; Ezekiel 47:12
# 2986             Future                 God      Genesis 3:17; Zechariah 14:7
# 2987           c. 95 AD               Angel                 Daniel 8:26; 12:4
# 2988           c. 95 AD        Jesus Christ        Malachi 3:1; Matthew 16:27
# 2989           c. 95 AD  Holy Spirit/Church                       Isaiah 55:1
#
#        book_name  book_number
# 0        Genesis          1.0
# 1        Genesis          1.0
# 2        Genesis          1.0
# 3        Genesis          1.0
# 4        Genesis          1.0
# ...          ...          ...
# 2985  Revelation         66.0
# 2986  Revelation         66.0
# 2987  Revelation         66.0
# 2988  Revelation         66.0
# 2989  Revelation         66.0
#
# [2990 rows x 9 columns]

# %%
mergeddf.to_excel('../acts_and_miracles/acts_and_miracles.xlsx', sheet_name='acts_and_miracles', index=False)
