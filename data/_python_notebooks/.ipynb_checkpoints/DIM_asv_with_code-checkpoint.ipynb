# %%
import pandas as pd

# %%
scripture_df = pd.read_csv(r'..\scripture\asv.csv')
scripture_df

# %%
scripture_df.insert(1, 'Reference Code', scripture_df.apply(lambda x: f"{x['Book Name']} {x['Chapter']}:{x['Verse']}", axis=1))
scripture_df

# %%
scripture_df.to_csv(r'..\acts_and_miracles\DIM_asv_with_code.csv', index=False)
