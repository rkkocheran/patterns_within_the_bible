# %%
# This notebook parses a specific KMZ file to extract a subset of the dataset for analysis

# %%
import zipfile
import xml.etree.ElementTree as ET
import os
from typing import List, Set, Dict, Any
import re

# %%
def parse_kmz_file(kmz_path: str) -> Dict[str, Any]:
    """
    Parse a KMZ file and extract column names from its dataset.
    
    Args:
        kmz_path (str): Path to the KMZ file
        
    Returns:
        Dict containing column names and other metadata
    """
    results = {
        'column_names': set(),
        'placemark_count': 0,
        'folders': [],
        'schemas': []
    }
    
    try:
        with zipfile.ZipFile(kmz_path, 'r') as kmz:
            # List all files in the KMZ
            file_list = kmz.namelist()
            
            # Find the main KML file (usually doc.kml or the largest .kml file)
            kml_files = [f for f in file_list if f.endswith('.kml')]
            
            if not kml_files:
                raise ValueError("No KML files found in the KMZ archive")
            
            # Use the first KML file or doc.kml if it exists
            main_kml = 'doc.kml' if 'doc.kml' in kml_files else kml_files[0]
            
            # Extract and parse the KML content
            with kmz.open(main_kml) as kml_file:
                kml_content = kml_file.read().decode('utf-8')
                
            # Parse the XML
            root = ET.fromstring(kml_content)
            
            # Define KML namespace
            namespace = {'kml': 'http://www.opengis.net/kml/2.2'}
            
            # Extract column names from different sources
            column_names = extract_column_names(root, namespace)
            results['column_names'] = column_names
            
            # Count placemarks
            placemarks = root.findall('.//kml:Placemark', namespace)
            results['placemark_count'] = len(placemarks)
            
            # Extract folder information
            folders = root.findall('.//kml:Folder', namespace)
            results['folders'] = [get_element_text(folder, 'kml:name', namespace) for folder in folders]
            
            # Extract schema information
            schemas = root.findall('.//kml:Schema', namespace)
            results['schemas'] = extract_schema_info(schemas, namespace)
            
    except Exception as e:
        print(f"Error parsing KMZ file: {e}")
        return results
    
    return results

def extract_column_names(root: ET.Element, namespace: Dict[str, str]) -> Set[str]:
    """Extract column names from various sources in the KML."""
    column_names = set()
    
    # 1. Extract from Schema definitions
    schemas = root.findall('.//kml:Schema', namespace)
    for schema in schemas:
        simple_fields = schema.findall('.//kml:SimpleField', namespace)
        for field in simple_fields:
            name = field.get('name')
            if name:
                column_names.add(name)
    
    # 2. Extract from ExtendedData
    extended_data_elements = root.findall('.//kml:ExtendedData', namespace)
    for extended_data in extended_data_elements:
        # SchemaData approach
        schema_data_elements = extended_data.findall('.//kml:SchemaData', namespace)
        for schema_data in schema_data_elements:
            simple_data_elements = schema_data.findall('.//kml:SimpleData', namespace)
            for simple_data in simple_data_elements:
                name = simple_data.get('name')
                if name:
                    column_names.add(name)
        
        # Data elements approach
        data_elements = extended_data.findall('.//kml:Data', namespace)
        for data in data_elements:
            name = data.get('name')
            if name:
                column_names.add(name)
    
    # 3. Extract from description fields (common in Google Earth exports)
    descriptions = root.findall('.//kml:description', namespace)
    for desc in descriptions:
        if desc.text:
            # Look for HTML table headers or common patterns
            html_columns = extract_columns_from_html_description(desc.text)
            column_names.update(html_columns)
    
    return column_names

def extract_columns_from_html_description(description_text: str) -> Set[str]:
    """Extract potential column names from HTML descriptions."""
    column_names = set()
    
    # Look for table headers
    th_pattern = r'<th[^>]*>(.*?)</th>'
    th_matches = re.findall(th_pattern, description_text, re.IGNORECASE | re.DOTALL)
    for match in th_matches:
        clean_text = re.sub(r'<[^>]+>', '', match).strip()
        if clean_text:
            column_names.add(clean_text)
    
    # Look for common key-value patterns
    # Pattern like "Name: Value" or "Name = Value"
    kv_pattern = r'(?:^|\n|<br[^>]*>)\s*([^:=\n]+)[:=]\s*[^:\n]+'
    kv_matches = re.findall(kv_pattern, description_text, re.IGNORECASE | re.MULTILINE)
    for match in kv_matches:
        clean_text = re.sub(r'<[^>]+>', '', match).strip()
        if clean_text and len(clean_text) < 50:  # Reasonable field name length
            column_names.add(clean_text)
    
    return column_names

def extract_schema_info(schemas: List[ET.Element], namespace: Dict[str, str]) -> List[Dict[str, Any]]:
    """Extract detailed schema information."""
    schema_info = []
    
    for schema in schemas:
        schema_data = {
            'name': schema.get('name'),
            'id': schema.get('id'),
            'fields': []
        }
        
        simple_fields = schema.findall('.//kml:SimpleField', namespace)
        for field in simple_fields:
            field_info = {
                'name': field.get('name'),
                'type': field.get('type'),
                'displayName': get_element_text(field, 'kml:displayName', namespace)
            }
            schema_data['fields'].append(field_info)
        
        schema_info.append(schema_data)
    
    return schema_info

def get_element_text(element: ET.Element, tag: str, namespace: Dict[str, str]) -> str:
    """Safely get text content from an XML element."""
    found_element = element.find(tag, namespace)
    return found_element.text if found_element is not None and found_element.text else ""

def print_results(results: Dict[str, Any]):
    """Print the parsing results in a formatted way."""
    print("="*60)
    print("KMZ FILE ANALYSIS RESULTS")
    print("="*60)
    
    print(f"\nColumn Names Found ({len(results['column_names'])}):")
    print("-" * 40)
    if results['column_names']:
        for i, column in enumerate(sorted(results['column_names']), 1):
            print(f"{i:2d}. {column}")
    else:
        print("No column names found")
    
    print(f"\nPlacemarks: {results['placemark_count']}")
    
    if results['folders']:
        print(f"\nFolders ({len(results['folders'])}):")
        for folder in results['folders']:
            print(f"  - {folder}")
    
    if results['schemas']:
        print(f"\nSchemas ({len(results['schemas'])}):")
        for schema in results['schemas']:
            print(f"  - {schema['name']} (ID: {schema['id']})")
            for field in schema['fields']:
                print(f"    • {field['name']} ({field['type']})")

def main():
    """Main function to run the KMZ parser."""
    kmz_file_path = r"C:\Users\MIKE.MK-DESKTOP\Documents\Career\Data_Analytics\Projects\patterns_within_the_bible\data\geo\all.kmz"
    
    if not os.path.exists(kmz_file_path):
        print(f"Error: File '{kmz_file_path}' not found.")
        return
    
    if not kmz_file_path.lower().endswith('.kmz'):
        print("Warning: File doesn't have .kmz extension. Proceeding anyway...")
    
    print(f"Parsing KMZ file: {kmz_file_path}")
    results = parse_kmz_file(kmz_file_path)
    
    print_results(results)
    
    # Return just the column names as a list for easy use
    return sorted(list(results['column_names']))
# Out:
# Parsing KMZ file: C:\Users\MIKE.MK-DESKTOP\Documents\Career\Data_Analytics\Projects\patterns_within_the_bible\data\geo\all.kmz
# ============================================================
# KMZ FILE ANALYSIS RESULTS
# ============================================================
#
# Column Names Found (45):
# ----------------------------------------
#  1. 1Chr <a href
#  2. 1Kgs <a href
#  3. 1Pet <a href
#  4. 1Sam <a href
#  5. 2Chr <a href
#  6. 2Kgs <a href
#  7. 2Sam <a href
#  8. 2Tim <a href
#  9. Acts <a href
# 10. Amos <a href
# 11. Col <a href
# 12. Dan <a href
# 13. Deut <a href
# 14. Esth <a href
# 15. Exod <a href
# 16. Ezek <a href
# 17. Ezra <a href
# 18. Gal <a href
# 19. Gen <a href
# 20. Hab <a href
# 21. Hos <a href
# 22. Isa <a href
# 23. Jer <a href
# 24. Job <a href
# 25. Joel <a href
# 26. John <a href
# 27. Josh <a href
# 28. Judg <a href
# 29. Lev <a href
# 30. Luke <a href
# 31. Mark <a href
# 32. Matt <a href
# 33. Mic <a href
# 34. Nah <a href
# 35. Neh <a href
# 36. Num <a href
# 37. Obad <a href
# 38. Ps <a href
# 39. Rev <a href
# 40. Rom <a href
# 41. Ruth <a href
# 42. Song <a href
# 43. Titus <a href
# 44. Zech <a href
# 45. Zeph <a href
#
# Placemarks: 7141
#
# Folders (1500):
#   - Abana (Abanah)
#   - Abarim
#   - Abarim
#   - Abdon
#   - Abel-beth-maacah (Abel Beth Maakah, Abel of Beth Maacah, Abel Beth Maachah, Abel)
#   - Abel-keramim
#   - Abel-meholah
#   - Abel-mizraim
#   - Abel-shittim (Acacia Meadow, Abel Acacia Grove)
#   - Abiezer (Abi-ezer)
#   - Abila
#   - Abila Lysaniou
#   - Abilene
#   - Abilene
#   - Abronah (Ebronah)
#   - Accad (Akkad)
#   - Acco (Akko, Accho)
#   - Achaia
#   - Achshaph (Akshaph, Acshaph)
#   - Achzib 1 (Akzib, Aczib)
#   - Achzib 2 (Akzib, Aczib)
#   - Adadah
#   - Adam
#   - Adamah
#   - Adami-nekeb (Nekeb)
#   - Adasa
#   - Addar (Adar)
#   - Addon (Addan)
#   - Addon / in Babylonia
#   - Adithaim
#   - Admah
#   - Adoraim
#   - Adramyttium
#   - Adriatic Sea (Sea of Adria, Adria)
#   - Adulis
#   - Adullam
#   - Adummim (Pass of Adummim, Ascent of Adummim)
#   - Aenon
#   - Ahava (Ahava Canal, Ahava River)
#   - Ahlab
#   - Ai 1
#   - Ai 2
#   - Ai 2 / in Moab 1
#   - Ai 3
#   - Aiath
#   - Aija
#   - Aijalon 1
#   - Aijalon 2
#   - Ain 1
#   - Ain 2
#   - Ain 3
#   - Akeldama (Field of Blood, Aceldama)
#   - Akrabbim (Scorpion Pass, Scorpion Ascent, Scorpions’ Ascent, Ascent of Akrabbim)
#   - Alemeth (Allemeth)
#   - Alexandria
#   - Allammelech (Allammelek, Alammelech, Allamelech)
#   - Allon
#   - Allon-bacuth (Allon Bakuth, Oak of Weeping, Allon Bachuth)
#   - Almon
#   - Almon-diblathaim (Almon-Diblatayim)
#   - Alush
#   - Ama
#   - Amad
#   - Amalek
#   - Amalek
#   - Amam
#   - Amana (Mount Amana)
#   - Amate
#   - Amaw
#   - Amaw / Ammon
#   - Ammah
#   - Ammon
#   - Ammon
#   - Amphipolis
#   - Anab
#   - Anaharath
#   - Ananiah
#   - Anathoth
#   - Ebenezer 2 (Eben-ezer)
#   - Ebez (Abez)
#   - Ebron (Abdon, Hebron)
#   - Ecbatana (Achmetha)
#   - Eden 1
#   - Eden 1 / in Babylonia
#   - Eden 1 / in Canaan
#   - Eden 1 / in Egypt
#   - Eden 2
#   - Eden 2 / Beth-eden
#   - Eder 1 (Migdal Eder, Tower of Eder, Edar)
#   - Eder 2
#   - Edom
#   - Edom
#   - Edrei 1
#   - Edrei 2
#   - Eglaim
#   - Eglath-shelishiyah
#   - Eglon
#   - Egypt
#   - Egypt
#   - Ekron
#   - Elam
#   - Elam
#   - Elath (Elat)
#   - El-bethel (El-beth-el)
#   - Elealeh
#   - Elim
#   - Elishah (Cyprus)
#   - Elkosh
#   - Ellasar
#   - Ellasar / Cappadocia
#   - Ellasar / Pontus
#   - Elon
#   - Elonbeth-hanan (Elon Bethhanan, Elon-beth-hanan, Elon of Beth-Hanan)
#   - El-paran
#   - Eltekeh
#   - Eltekon
#   - Eltolad
#   - Emek-keziz (Keziz)
#   - Emmaus
#   - Enaim (Eynayim)
#   - Enam
#   - En-dor (Endor)
#   - Eneglaim (En Eglaim)
#   - En-gannim 1
#   - En-gannim 2
#   - Engedi (En Gedi)
#   - En-haddah
#   - En-hakkore (The Spring of the One Who Cried Out, Hakkore Spring, The Spring of Ha-Qore)
#   - En-hazor
#   - En-rimmon
#   - En-rogel
#   - En-shemesh
#   - En-tappuah (spring of Tappuah)
#   - Ephah
#   - Ephah / Midian
#   - Ephes-dammim (Pas Dammim, Pasdammim)
#   - Ephesus
#   - Ephraim 1
#   - Ephraim 2
#   - Ephraim 3
#   - Ephraim 3 / Ephraim 3
#   - Ephraim Gate (Gate of Ephraim)
#   - Ephrath
#   - Ephrathah (Ephratah)
#   - Ephron 1
#   - Ephron 2 (Ephrain)
#   - Erech (Uruk)
#   - Eridu
#   - Esek
#   - Eshan (Eshean)
#   - Eshtaol
#   - Eshtemoa
#   - Etam 1
#   - Etam 2
#   - Etam 3 (Etah)
#   - Etham
#   - Ether 1
#   - Ether 2
#   - Ethiopia (Cush)
#   - Ethiopia
#   - Eth-kazin (Ittah-kazin)
#   - Etruria
#   - Euphrates (Euphrates River, River)
#   - Ezel
#   - Ezem (Azem)
#   - Ezion-geber
#   - Fair Havens
#   - Fish Gate
#   - Forum of Appius (Market of Appius, Forum on the Appian Way, Appii Forum)
#   - Fountain Gate
#   - Gaash (Nahale-gaash)
#   - Gabbatha
#   - Gadara
#   - Galatia
#   - Galatia
#   - Galilee 1
#   - Galilee 1
#   - Galilee 2 (Gilgal)
#   - Galilee 2
#   - Gallim
#   - Gamad (Gammad)
#   - Gareb (Hill of Gareb)
#   - Gate of the Foundation (Foundation Gate)
#   - Gate of the Guard (Guard Gate, Gate of the Prison)
#   - Gate of Yeshanah (Jeshanah Gate, Ancient Gate, Old Gate, Old City Gate)
#   - Gath 1
#   - Gath 2
#   - Gath 3
#   - Gath-hepher
#   - Gath-padalla
#   - Gath-rimmon 1
#   - Gath-rimmon 2
#   - Gaza
#   - Geba 1
#   - Maacah (Maakah)
#   - Maacah
#   - Maarath
#   - Maareh-geba
#   - Macedonia
#   - Machbenah (Makbenah, Machbena, Macbenah)
#   - Machpelah
#   - Madiama
#   - Madmannah
#   - Madmen
#   - Madmenah
#   - Madon
#   - Magadan (Magdala)
#   - Magbish
#   - Magdala
#   - Magdalsenna
#   - Magdolum
#   - Magog
#   - Magog / Babylonia
#   - Mahalab (Hebel, Mehebel)
#   - Mahanaim
#   - Mahaneh-dan 1 (Camp of Dan)
#   - Mahaneh-dan 2 (Camp of Dan)
#   - Makaz
#   - Makaz / in the Ayalon Valley
#   - Makheloth
#   - Makkedah
#   - Malta (Melita)
#   - Mamre
#   - Manahath
#   - Maon
#   - Marah
#   - Mareal (Maralah)
#   - Mareshah
#   - Maroth
#   - Masrekah
#   - Massah
#   - Mattanah
#   - Mearah (Arah)
#   - Meconah (Mekonah)
#   - Medeba
#   - Media
#   - Megiddo
#   - Me-jarkon
#   - Memphis (Noph)
#   - Mephaath
#   - Merathaim
#   - Meribah 1 (Waters of Meribah)
#   - Meribah 2
#   - Merom
#   - Meronoth
#   - Meroz
#   - Mesha
#   - Meshech (Meshek)
#   - Mesopotamia (Aram Naharaim)
#   - Mesopotamia / Aram-naharaim
#   - Metheg-ammah (Gath)
#   - Mezahab (Me-Zahab)
#   - Michmash (Mikmash, Micmash)
#   - Michmethath (Mikmethath, Micmethath, Michmethah)
#   - Middin
#   - Middle Gate
#   - Midian
#   - Midian
#   - Migdal-el
#   - Migdal-gad
#   - Migdol 1
#   - Migdol 2
#   - Migdol 3
#   - Migron 1
#   - Migron 2
#   - Miletus
#   - Millo
#   - Minni
#   - Minnith
#   - Misgab
#   - Misgab / in Moab 1
#   - Mishal
#   - Misrephoth-maim (Brook Misrephoth)
#   - Mithkah (Mithcah)
#   - Mitylene
#   - Mizpah 1 (Mizpeh)
#   - Mizpah 2 (Mizpeh)
#   - Mizpah 3
#   - Mizpah 4 (Galeed)
#   - Mizpeh 1 (Mizpah)
#   - Mizpeh 2 (Mizpah)
#   - Mizpeh 3 (Mizpah)
#   - Mizpeh 3 / in Moab 1
#   - Moab 1
#   - Moab 1 / Moab 1
#   - Moab 2
#   - Moab 2 / Moab 2
#   - Moladah
#   - Moreh 1
#   - Moreh 2
#   - Moresheth-gath (Moresheth)
#   - Moriah
#   - Mortar (Hollow, Maktesh)
#   - Moseroth (Moserah)
#   - Most Holy Place 1 (Most Holy)
#   - Most Holy Place 2 (Holy of Holies)
#   - Mount Baalah (Baalah)
#   - Mount Baal-hermon (Baal-hermon)
#   - Mount Bashan
#   - Mount Carmel (Carmel)
#   - Mount Ebal (Ebal)
#   - Mount Ephraim (Ephraim)
#   - Mount Ephraim
#   - Mount Ephron (Ephron)
#   - Mount Esau (Esau)
#   - Mount Esau / region around Jebel esh Shera
#   - Mount Gerizim (Gerizim)
#   - Mount Gilboa (Gilboa)
#   - Mount Gilead (Mount of Gilead, Gilead)
#   - Mount Halak (Halak)
#   - Mount Heres (Har-heres, Heres)
#   - Mount Hermon (Hermon)
#   - Mount Hor 1 (Hor)
#   - Mount Hor 2 (Hor)
#   - Mount Horeb (Horeb, Mount Sinai)
#   - Mount Jearim (Jearim)
#   - Mount Lebanon (Lebanon)
#   - Mount Mizar (Hill Mizar, Mizar)
#   - Mount Moriah (Moriah)
#   - Mount Nebo (Nebo)
#   - Mount of Olives (Olivet)
#   - Mount Paran (Paran)
#   - Mount Paran / in Paran
#   - Mount Perazim (Perazim)
#   - Mount Seir 1 (Seir)
#   - Mount Seir 1 / region around Jebel esh Shera
#   - Mount Seir 2 (Seir)
#   - Mount Shepher (Mount Shapher, Shapher)
#   - Mount Sinai (Sinai)
#   - Mount Tabor (Tabor)
#   - Mount Zalmon (Zalmon)
#   - Mount Zemaraim (Zemaraim)
#   - Mount Zion (Zion)
#   - Mozah
#   - Muster Gate (Inspection Gate, Miphkad Gate, Enrollment Gate, Miphkad)
#   - Myra
#   - Mysia
#   - Naamah 1
#   - Naamah 2
#   - Naamah 2 / Sheba
#   - Naamah 2 / in Edom
#   - Naarah (Naarath)
#   - Naaran
#   - Nahalal
#   - Nahaliel
#   - Nahor
#   - Nahuru
#   - Nain
#   - Naioth
#   - Naphoth-dor (Naphath-dor, Napheth, Naphat of Dor)
#   - Naphoth-dor / region around Tel Dor
#   - Nazareth
#   - Neah
#   - Neapolis
#   - Neballat
#   - Nebo 1
#   - Nebo 2
#   - Nebo 3
#   - Negeb (Negev, South)
#   - Negeb
#   - Nehelam
#   - Neiel
#   - Nephtoah (Waters of Nephtoah)
#   - Netaim
#   - Netophah
#   - New Gate
#   - Nezib
#   - Nibshan
#   - Nicopolis
#   - Nile (River, Sihor)
#   - Nimrah
#   - Nimrim (Waters of Nimrim)
#   - Nimrod
#   - Nimrod / Assyria
#   - Nineveh
#   - Nob
#   - Nobah 1
#   - Nobah 2
#   - Nod
#   - Nohah
#   - Nophah
#   - Nophah / in Moab 1
#   - North
#   - North Gate
#   - Nuhashe
#   - Nuhashe
#   - Oboth
#   - Old Pool
#   - Ono
#   - Ophel
#   - Ophir
#   - Ophir / southwestern Arabia
#   - Ophni
#   - Ophrah 1
#   - Ophrah 2
#   - Paddan-aram (Padan Aram)
#   - Paddan-aram / Aram-naharaim
#   - Pamphylia
#   - Paphos
#   - Parah
#   - Paran (Desert of Paran, Wilderness of Paran)
#   - Paran
#   - Parbar
#   - Parvaim
#   - Patara
#   - Pathros (Upper Egypt)
#   - Patmos
#   - Pau
#   - Pekod
#   - Pekod
#   - Pelusium (Sin)
#   - Penuel (Peniel)
#   - People’s Gate (Gate of the People)
#   - Peor
#   - Perez-uzzah (Outburst Against Uzzah, Perez Uzza)
#   - Perga
#   - Pergamum (Pergamos)
#   - Persia
#   - Pethor
#   - Pharpar
#   - Philadelphia
#   - Philippi
#   - Philistia
#   - Philistia
#   - Phoenicia (Phenice)
#   - Phoenicia
#   - Phoenix (Phenice)
#   - Phrygia
#   - Pi-beseth (Bubastis)
#   - Pi-hahiroth
#   - Pirathon
#   - Pisgah
#   - Pisgah / Abarim
#   - Tigris (Hiddekel)
#   - Timnah 1 (Timnath)
#   - Timnah 2
#   - Timnah 3 (Timnath)
#   - Timnath-heres (Timnath-serah)
#   - Tiphsah 1
#   - Tiphsah 2 (Tappuah)
#   - Tirzah
#   - Tishbe
#   - Tjaru
#   - Tob
#   - Tochen (Token)
#   - Tophel
#   - Topheth (Tophet)
#   - Tower of Hananel
#   - Tower of Shechem
#   - Tower of the Hundred
#   - Tower of the Ovens (Tower of Furnaces)
#   - Trachonitis (Traconitis)
#   - Troas
#   - Trogyllium
#   - Tubal
#   - Tubal / Tabal
#   - Tyre
#   - Ulai (Ulai River)
#   - Ummah (Umah)
#   - Umman Manda
#   - Uphaz (Ufaz)
#   - Uphaz / southwestern Arabia
#   - Upper Beth-horon
#   - Upper Gulloth
#   - Upper Pool
#   - Upu
#   - Upu
#   - Uqnu
#   - Ur 1
#   - Ur 1 / Urartu
#   - Ur 2
#   - Ura
#   - Uz
#   - Uz / in Edom
#   - Uz / Hauran
#   - Uz / Negeb
#   - Uz / Edom
#   - Uzal (Izal)
#   - Uzza
#   - Uzzen-sheerah (Uzzen-sherah)
#   - Valley Gate
#   - Valley of Achor (Valley of Trouble)
#   - Valley of Aijalon (Ajalon)
#   - Valley of Aijalon / Ayalon Valley
#   - Valley of Aven (Wicked Valley, Aven)
#   - Valley of Aven / Beth-eden
#   - Valley of Baca (Valley of Baka, Baca Valley, Valley of Weeping)
#   - Valley of Beracah (Valley of Berakah, Valley of Berachah, Valley of Blessing, Berachah)
#   - Valley of Decision
#   - Valley of Elah
#   - Valley of Eshcol (Valley of Eshkol, Wadi Eshcol, Eshcol Valley, Eshcol)
#   - Valley of Gerar (Gerar Valley)
#   - Valley of Gibeon (Gibeon)
#   - Valley of Hamon-gog (Valley of Gog’s Hordes, Hordes of Gog Valley, Hamon-gog)
#   - Valley of Hamon-gog / in Abarim
#   - Valley of Hebron (Hebron Valley, Hebron)
#   - Valley of Hinnom (Valley of the Son of Hinnom, Valley of Ben Hinnom, Valley of Slaughter, Ben Hinnom Valley)
#   - Valley of Iphtahel (Valley of Iphtah El, Iphtah-el Valley, Valley of Jiphthah El, Jiphthah-el)
#   - Valley of Jehoshaphat
#   - Valley of Jericho (Plain, Jordan Valley)
#   - Valley of Jezreel (Jezreel Valley)
#   - Valley of Lebanon (Lebanon Valley)
#   - Valley of Mizpeh (Valley of Mizpah, Mizpah Valley)
#   - Valley of Rephaim (Rephaim Valley)
#   - Valley of Salt (Salt Valley)
#   - Valley of Shaveh (Shaveh Valley)
#   - Valley of Shittim (Wadi Shittim, Valley of Acacia Trees, Valley of Acacias, Shittim)
#   - Valley of Siddim (Siddim Valley, Siddim)
#   - Valley of Sorek (Sorek Valley)
#   - Valley of Succoth (Valley of Sukkoth, Vale of Succoth)
#   - Valley of the Arnon (Arnon Gorge, Valley of Arnon, Wadi Arnon, Arnon Valley, River Arnon, Arnon)
#   - Valley of Zeboim (Valley of Zeboyim, Zeboim Valley)
#   - Valley of Zephathah (Zephathah Valley)
#   - Valley of Zered (Zered Valley, Wadi Zered)
#   - Waheb (Zahab)
#   - Washer’s Field (Launderer’s Field, Fuller’s Field)
#   - Water Gate
#   - Waters of Jericho
#   - Waters of Merom
#   - Way of Holiness (Highway of Holiness, Holy Way)
#   - Way of the Red Sea (Red Sea)
#   - West Gate
#   - Wilderness of Maon (Desert of Maon)
#   - Wilderness of Maon
#   - Wilderness of Sinai (Desert of Sinai)
#   - Wilderness of Ziph (Desert of Ziph, Ziph)
#   - Wilderness of Ziph
#   - Wildgoats’ Rocks (Crags of the Wild Goats, Rocks of the Mountain Goats, Rocks of the Wild Goats)
#   - Yiron (Iron)
#   - Zaanan
#   - Zaanannim
#   - Zair
#   - Zair / in the region around Jebel esh Shera
#   - Zalmon (Mount Zalmon, Salmon)
#   - Zalmonah
#   - Zanoah 1
#   - Zanoah 2
#   - Zaphon 1
#   - Zaphon 2
#   - Zarephath
#   - Zarethan (Zaretan)
#   - Zeboiim (Zeboyim, Zeboim)
#   - Zeboim (Zeboyim)
#   - Zedad
#   - Zela (Zelah)
#   - Zelzah
#   - Zemaraim
#   - Zenan
#   - Zephath
#   - Zer
#   - Zered (Zered Valley, Wadi Zered, Zered Brook, Valley of the Zered)
#   - Zeredah 1 (Zereda)
#   - Zeredah 2 (Zarethan, Zeredathah)
#   - Zererah (Zererath)
#   - Zereth-shahar (Zareth-shahar)
#   - Ziddim
#   - Ziklag
#   - Zimri
#   - Zin 1 (Desert of Zin, Wilderness of Zin)
#   - Zin 1 / Zin Desert
#   - Zin 2
#   - Zin 2 / Zin Desert
#   - Zin 2 / in the Zin Desert
#   - Zion (Jerusalem)
#   - Zior
#   - Ziph 1
#   - Ziph 2
#   - Ziphron
#   - Ziz (Pass of Ziz, Ascent of Ziz)
#   - Zoan
#   - Zoar
#   - Zobah
#   - Zobah
#   - Zophim (Lookout Field)
#   - Zophim / in Abarim
#   - Zorah
#   - Zuph
#
# Column names list: ['1Chr <a href', '1Kgs <a href', '1Pet <a href', '1Sam <a href', '2Chr <a href', '2Kgs <a href', '2Sam <a href', '2Tim <a href', 'Acts <a href', 'Amos <a href', 'Col <a href', 'Dan <a href', 'Deut <a href', 'Esth <a href', 'Exod <a href', 'Ezek <a href', 'Ezra <a href', 'Gal <a href', 'Gen <a href', 'Hab <a href', 'Hos <a href', 'Isa <a href', 'Jer <a href', 'Job <a href', 'Joel <a href', 'John <a href', 'Josh <a href', 'Judg <a href', 'Lev <a href', 'Luke <a href', 'Mark <a href', 'Matt <a href', 'Mic <a href', 'Nah <a href', 'Neh <a href', 'Num <a href', 'Obad <a href', 'Ps <a href', 'Rev <a href', 'Rom <a href', 'Ruth <a href', 'Song <a href', 'Titus <a href', 'Zech <a href', 'Zeph <a href']

# %%
if __name__ == "__main__":
    column_names = main()
    print(f"\nColumn names list: {column_names}")

# %% [markdown]
# results = parse_kmz_file(r"C:\Users\MIKE.MK-DESKTOP\Documents\Career\Data_Analytics\Projects\patterns_within_the_bible\data\geo\all.kmz")
# column_names = sorted(list(results['column_names']))
# print(column_names)
